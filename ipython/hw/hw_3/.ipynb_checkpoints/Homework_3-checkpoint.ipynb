# %% [markdown]
# ### Introduction to Data Science
# ## Homework 3: Due 5pm to My Mailbox (2nd Floor, 19 W 4th St) Wednesday April 19th

# %% [markdown]
# Student Name:Aman Kumar Mahato
#
# Student Netid:akm533
# ***

# %% [markdown]
# In this assignment we will be looking at data generated by particle physicists to test whether machine learning can help classify whether certain particle decay experiments identify the presence of a Higgs Boson. One does not need to know anything about particle physics to do well here, but if you are curious, full feature and data descriptions can be found here:
#
# - https://www.kaggle.com/c/higgs-boson/data
# - http://higgsml.lal.in2p3.fr/files/2014/04/documentation_v1.8.pdf
#
# The goal of this assignment is to learn to use cross-validation for model selection. We’ll also use learning curve analysis to understand how well different algorithms make use of limited data. For more documentation on cross-validation with Python, you can consult the following:
#
# - http://scikit-learn.org/stable/modules/cross_validation.html#cross-validation

# %% [markdown]
# ### Part 1: Data preparation
# Create a data preparation and cleaning function that does the following:
# - Has a single input that is a file name string
# - Reads data (the data is comma separated, has a row header and the first column `EventID` is the index) into a pandas `dataframe`
# - Cleans the data
#   - Convert the feature `Label` to numeric (choose the minority class to be equal to 1)
#     - Create a feature `Y` with numeric label
#     - Drop the feature `Label`
#   - If a feature has missing values (i.e., `-999`):
#     - Create a dummy variable for the missing value
#       - Call the variable `orig_var_name` + `_mv` where `orig_var_name` is the name of the actual var with a missing value
#       - Give this new variable a 1 if the original variable is missing
#     - Replace the missing value with the average of the feature (make sure to compute the mean on records where the value isn't missing). You may find pandas' `.replace()` function useful.
# - After the above is done, rescales the data so that each feature has zero mean and unit variance (hint: look up sklearn.preprocessing)
# - Returns the cleaned and rescaled dataset
#
# Hint: as a guide, this function can easily be done in less than 15 lines.

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
def cleanBosonData(file_path): 
    #reads the file from the source and creates a pandas dataframe
    df = pd.read_csv(file_path,index_col = 0)
    #replace the attribute "Label" with 0 and 1 as mentioned in the question
    df['Y'] = df['Label'].replace(['s','b'],[1,0])
    df = df.drop('Label',1)
    orig_cols = df.drop('Y',1)
    for x in orig_cols.columns:
        #replacing all the -999 with NAn
        df[x] = df[x].replace([-999],[np.NaN])
        if(df[x].isnull().values.any()):
            df[x + '_mv'] = np.isnan(df[x])*1
        df[x] = df[x].replace([np.NaN], df[x].mean(axis=0))
        scale = StandardScaler()
        df[x] = scale.fit_transform(df[x],df['Y']) 
    return df

# %% [markdown]
# ### Part 2: Basic evaluations
# In this part you will build an out-of-the box logistic regression (LR) model and support vector machine (SVM). You will then plot ROC for the LR and SVM model.

# %% [markdown]
# 1\. Clean the two data files included in this assignment (`data/boson_training_cut_2000.csv` and `data/boson_testing_cut.csv`) and use them as training and testing data sets.

# %%
data_train = cleanBosonData("data/boson_training_cut_2000.csv")
data_test = cleanBosonData("data/boson_testing_cut.csv")
# Out:
# /Users/amanmahato/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/amanmahato/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/amanmahato/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/amanmahato/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/amanmahato/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/amanmahato/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/amanmahato/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/amanmahato/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/amanmahato/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/amanmahato/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/amanmahato/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/amanmahato/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/amanmahato/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/amanmahato/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/amanmahato/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/amanmahato/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/amanmahato/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/amanmahato/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/amanmahato/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/amanmahato/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/amanmahato/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/amanmahato/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/amanmahato/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/amanmahato/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/amanmahato/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/amanmahato/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/amanmahato/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/amanmahato/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/amanmahato/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/amanmahato/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/amanmahato/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/amanmahato/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/amanmahato/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/amanmahato/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/amanmahato/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/amanmahato/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)

# %% [markdown]
# 2\. On the training set, build the following models:
#
# - A logistic regression using sklearn's `linear_model.LogisticRegression()`. For this model, use `C=1e30`.
# - An SVM using sklearn's `svm.svc()`. For this model, specify that `kernel="linear"`.
#
# For each model above, plot the ROC curve of both models on the same plot. Make sure to use the test set for computing and plotting. In the legend, also print out the Area Under the ROC (AUC) for reference.

# %%
import matplotlib
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression 
from sklearn.svm import SVC
from sklearn import metrics
# %matplotlib inline
#Logistic Regression Classifier
LR = LogisticRegression(C=10^30)
#SVM Classifier
SVM = SVC(kernel='linear', probability=True)
#Training and building the model
LR = LR.fit(data_train.drop('Y',1),data_train['Y'])
SVM = SVM.fit(data_train.drop('Y',1),data_train['Y'])
#Predicting the score
a=data_test.drop('Y', 1)
predict_LR = LR.predict_proba(a)
predict_SVM = SVM.predict_proba(a)
false_positive_LR, true_positive_LR, thresholds = metrics.roc_curve(data_test['Y'], predict_LR[:, 1])
false_positive_SVM, true_positive_SVM, thresholds = metrics.roc_curve(data_test['Y'], predict_SVM[:, 1])
roc_auc_LR = metrics.auc(false_positive_LR, true_positive_LR)
roc_auc_SVM = metrics.auc(false_positive_SVM, true_positive_SVM)
plt.figure(1)
plt.plot(false_positive_LR, true_positive_LR, label='LR, AUC: {}'.format(roc_auc_LR)) 
plt.plot(false_positive_SVM, true_positive_SVM, label='SVM, AUC: {}'.format(roc_auc_SVM)) 
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('FPR-->')
plt.ylabel('TPR-->')
plt.title('Receiver Operator Characteristics curve')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# 3\. Which of the two models is generally better at ranking the test set? Are there any classification thresholds where the model identified above as "better" would underperform the other in a classification metric (such as TPR)?

# %% [markdown]
# In general, Logistic Regression works better at ranking the test set. But one should note that it works well only for True Posotive Rate of 0.25 and False Positive Rate of 0.05 or somewhere close to these values. If we are very strict with the classification and want the false positive rate below 5%, we can use either of the Logistic Regression or the SVM and both will work fine and will give the same result or results which are very close to each other.

# %% [markdown]
# ### Part 3: Model selection with cross-validation
# We think we might be able to improve the performance of the SVM if we perform a grid search on the hyper-parameter $C$.  Because we only have 1000 instances, we will have to use cross-validation to find the optimal $C$.

# %% [markdown]
# 1\. Write a cross-validation function that does the following:
# - Takes as inputs a dataset, a label name, # of splits/folds (`k`), a sequence of values for $C$ (`cs`)
# - Performs two loops
#   - Outer Loop: `for each f in range(k)`:
#     - Splits the data into `data_train` & `data_validate` according to cross-validation logic
#   - Inner Loop: `for each c in cs`:
#     - Trains an SVM on training split with `C=c, kernel="linear"`
#     - Computes AUC_c_k on validation data
#     - Stores AUC_c_k in a  dictionary of values
# - Returns a dictionary, where each key-value pair is: `c:[auc-c1,auc-c2,..auc-ck]`

# %%
#importing all the necessary python libraries
from sklearn.metrics import roc_curve, auc
from sklearn.svm import SVC
from collections import defaultdict
import collections
def xValSVM(dataframe, label_name, k, cs):
    aucs = defaultdict(list)
    for f in range(k):
        data_val = dataframe.iloc[int(np.floor(f*len(dataframe)/k)):int(np.ceil((f+1)*len(dataframe)/k))]
        data_train = dataframe[~dataframe.isin(data_val)].dropna()
        for i, c in enumerate(cs):
            clf_SVM = SVC(kernel='linear',C=c,probability=True)
            pred = clf_SVM.fit(data_train.drop(label_name,1),data_train[label_name]).predict_proba(data_val.drop(label_name,1))
            fpr, tpr, thresholds = roc_curve(data_val[label_name], pred[:, 1])
            AUC_c_k=auc(fpr, tpr)
            aucs[c].append(AUC_c_k)
    aucs = collections.OrderedDict(sorted(aucs.items()))
    return aucs

# %% [markdown]
# 2\. Using the function written above, do the following:
# - Generate a sequence of 10 $C$ values in the interval `[10^(-8), ..., 10^1]` (i.e., do all powers of 10 from -8 to 1).
# 2.	Call aucs = xValSVM(train, ‘Y’, 10, cs)
# 3.	For each c in cs, get mean(AUC) and StdErr(AUC)
# 4.	Compute the value for max(meanAUC-StdErr(AUC)) across all values of c.
# 5.	Generate a plot with the following:
# a.	Log10(c) on the x-axis
# b.	1 series with mean(AUC) for each c
# c.	1 series with mean(AUC)-stderr(AUC) for each c (use ‘k+’ as color pattern)
# d.	1 series with mean(AUC)+stderr(AUC) for each c (use ‘k--‘ as color pattern)
# e.	a reference line for max(AUC-StdErr(AUC)) (use ‘r’ as color pattern)
#
# Then answer the question: Did the model parameters selected beat the out-of-the-box model for SVM?

# %%
import numpy as np 
import pandas as pd
cs = [10.**i for i in np.arange(-8,2)] 
aucs=xValSVM(data_train,'Y',10,cs)
mean = []
stdErr = []
for key,value in aucs.items(): 
    mean.append(np.mean(np.array(value))) 
    stdErr.append(np.std(np.array(value)))
meanAUC_diff_StdErr= np.max(np.array(mean) - np.array(stdErr))
means = np.array(mean)
mean_min_std = np.array(mean)-np.array(stdErr)
mean_plus_std = np.array(mean)+np.array(stdErr)
x = np.log10(np.array(cs))
#plotting as per the question
plt.plot(x,means)
plt.plot(x,mean_min_std,'k+') 
plt.plot(x,mean_plus_std,'k--') 
plt.plot(x,np.ones(len(x))*meanAUC_diff_StdErr,'r') 
plt.xlabel("Log10(c)")
plt.ylabel("AUC")
plt.title("Area Under Curve vs. C")
plt.show()

# %% [markdown]
# No, we can see from the graph above, after C =10^0 and C=10^1; the graph is same as for the out of the box SVM.

# %% [markdown]
# 3\. Which of the two algorithms are more suitable for smaller sample sizes, given the set of features? If it costs twice the investment to run enough experiments to double the data, do you think it is a worthy investment?

# %% [markdown]
# For smaller sample sizes, its always good to go with Logistic Regression as it is faster and is more accurate. Besides, folding the data set into smaller data size will increase the biased cross validation. But we should be more considerate with the sample data size and true positives and thus the size of the data. Hence the large sampel size can be useful and thus I think it will be a worthy investment.

# %% [markdown]
# 4\. Is there a reason why cross-validation might be biased? If so, in what direction is it biased? (Hint: refer to ESL figure 7.8)?

# %% [markdown]
# If we verify the behaviour of the prediction error according to the size of the dataset, we will see that for a small sample size, the predictions results in overestimate and leads to upwards biased cross validation. For an instance, lets say we have out sample data with 10 records and we are doing 5 folds cross validation, the prediction from 8 records will result in considerate overestimate of the prediction error. In our case, we have small sample size and hence it is the case of upward biased.
